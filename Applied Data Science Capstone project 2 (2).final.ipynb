# %%
#!conda install requests
#!conda install beautifulsoup4
#!conda install -c conda-forge geopy --yes

# %%
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim
import requests

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

from pandas.io.json import json_normalize
import urllib.request
from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ###   Assign url to the wikipedia page

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(page, "lxml")

# %% [markdown]
# ### Use Prettify function of BeautifulSoup library to extract data

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of postal codes of Canada: M - Wikipedia
#   </title>
#   <script>
# ...

# %%
all_tables=soup.find_all("table")
all_tables
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Postal Code
#  </th>
#  <th>Borough
#  </th>
#  <th>Neighborhood
#  </th></tr>
#  <tr>
#  <td>M1A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>
#  <tr>
#  <td>M2A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>
#  <tr>
#  <td>M3A
#  </td>
#  <td>North York
#  </td>
#  <td>Parkwoods
#  </td></tr>
#  <tr>
#  <td>M4A
#  </td>
#  <td>North York
#  </td>
#  <td>Victoria Village
#  </td></tr>
#  <tr>
#  <td>M5A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Regent Park, Harbourfront
#  </td></tr>
#  <tr>
#  <td>M6A
#  </td>
#  <td>North York
#  </td>
#  <td>Lawrence Manor, Lawrence Heights
#  </td></tr>
#  <tr>
#  <td>M7A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Queen's Park, Ontario Provincial Government
#  </td></tr>
#  <tr>
#  <td>M8A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>
#  <tr>
#  <td>M9A
#  </td>
#  <td>Etobicoke
#  </td>
# ...

# %% [markdown]
# ###  Extract table from wikipedia page

# %%
right_table=soup.find('table', class_='wikitable sortable')
right_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Postal Code
# </th>
# <th>Borough
# </th>
# <th>Neighborhood
# </th></tr>
# <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>
# <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>
# <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park, Harbourfront
# </td></tr>
# <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor, Lawrence Heights
# </td></tr>
# <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park, Ontario Provincial Government
# </td></tr>
# <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue, Humber Valley Village
# </td></tr>
# <tr>
# <td>M1B
# ...

# %% [markdown]
# ### Append table values into lists

# %%
A=[]
B=[]
C=[]

for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %% [markdown]
# ###   Add columns names to dataframe and Print dataframe

# %%
df=pd.DataFrame(A,columns=['Postal Code'])
df['Borough']=B
df['Neighborhood']=C
df.head()
# Out:
#   Postal Code            Borough                Neighborhood
# 0        M1A
#       Not assigned
#                Not assigned
#
# 1        M2A
#       Not assigned
#                Not assigned
#
# 2        M3A
#         North York
#                   Parkwoods
#
# 3        M4A
#         North York
#            Victoria Village
#
# 4        M5A
#   Downtown Toronto
#   Regent Park, Harbourfront

# %% [markdown]
# ###  Filter only those values from dataframe , where Borough is assigned

# %%
df_filtered=df[df["Borough"]!="Not assigned\n"]
df_filtered.head()
# Out:
#   Postal Code            Borough                                  Neighborhood
# 2        M3A
#         North York
#                                     Parkwoods
#
# 3        M4A
#         North York
#                              Victoria Village
#
# 4        M5A
#   Downtown Toronto
#                     Regent Park, Harbourfront
#
# 5        M6A
#         North York
#              Lawrence Manor, Lawrence Heights
#
# 6        M7A
#   Downtown Toronto
#   Queen's Park, Ontario Provincial Government

# %% [markdown]
# ### Find if there are any duplicate Postal codes

# %%
df_dup=df_filtered[df_filtered.duplicated(["Postal Code"])]
df_dup
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# ###   Find if there is any neighborhood where value is 'Not assigned'

# %%
df_f=df_filtered[df_filtered["Neighborhood"]=="Not assigned\n"]
df_f
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# ### Print the shape of final Dataframe

# %%
df_filtered.shape
# Out:
# (103, 3)

# %%
df_new=df_filtered
df_new.head()
# Out:
#   Postal Code            Borough                                  Neighborhood
# 2        M3A
#         North York
#                                     Parkwoods
#
# 3        M4A
#         North York
#                              Victoria Village
#
# 4        M5A
#   Downtown Toronto
#                     Regent Park, Harbourfront
#
# 5        M6A
#         North York
#              Lawrence Manor, Lawrence Heights
#
# 6        M7A
#   Downtown Toronto
#   Queen's Park, Ontario Provincial Government

# %%
df_new=df_filtered
df_new.head()
# Out:
#   Postal Code            Borough                                  Neighborhood
# 2        M3A
#         North York
#                                     Parkwoods
#
# 3        M4A
#         North York
#                              Victoria Village
#
# 4        M5A
#   Downtown Toronto
#                     Regent Park, Harbourfront
#
# 5        M6A
#         North York
#              Lawrence Manor, Lawrence Heights
#
# 6        M7A
#   Downtown Toronto
#   Queen's Park, Ontario Provincial Government

# %% [markdown]
# ###  Add new columns Latitude , Longitude to data

# %%
df_new = df_new.reindex(df_new.columns.tolist() + ['Latitude','Longitude'], axis=1)

# %%
df_new.head()
# Out:
#   Postal Code            Borough  \
# 2        M3A
#         North York
#
# 3        M4A
#         North York
#
# 4        M5A
#   Downtown Toronto
#
# 5        M6A
#         North York
#
# 6        M7A
#   Downtown Toronto
#
#
#                                    Neighborhood  Latitude  Longitude
# 2                                    Parkwoods
#        NaN        NaN
# 3                             Victoria Village
#        NaN        NaN
# 4                    Regent Park, Harbourfront
#        NaN        NaN
# 5             Lawrence Manor, Lawrence Heights
#        NaN        NaN
# 6  Queen's Park, Ontario Provincial Government
#        NaN        NaN

# %%
geolocator = Nominatim(user_agent="can_explorer")
print(geolocator)

# %% [markdown]
# ### Invoke Geolocator ,geocode function to get latitude, longitude

# %%
index=0
df_new = df_new.replace('\n',' ', regex=True)
for index, row in df_new.iterrows():
        address = df_new.at[index,'Neighborhood']
        add1=address.rsplit(",")
        add2 =address + ' ,Canada'
        location = geolocator.geocode(add2)
        if (location):
            lat=location.latitude
            long=location.longitude
            df_new.at[index,'Latitude']= lat 
            df_new.at[index,'Longitude']= long
        else :
            address2= df_new.at[index,'Borough']
            loc=geolocator.geocode(address2)
            lat=loc.latitude
            long=loc.longitude
            df_new.at[index,'Latitude']= lat 
            df_new.at[index,'Longitude']= long

# %% [markdown]
# ###   Dataframe with Latitude and Longitude

# %% [markdown]
# df_new

# %% [markdown]
# ### Create Map of Canada - and mark markers

# %%
geolocator = Nominatim(user_agent="can_explorer")
print(geolocator)
address = 'Ottawa, Canada'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Canada are {}, {}.'.format(latitude, longitude))
# Out:
# ...
# The geograpical coordinate of Canada are 45.421106, -75.690308.

# %% [markdown]
# ### Different locations marked on Canada Map

# %%
# create map of Canada using latitude and longitude values
map_canada = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_new['Latitude'], df_new['Longitude'], df_new['Borough'], df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_canada)  
    
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
